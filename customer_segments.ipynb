# %% [markdown]
# # 机器学习纳米学位
# ## 非监督学习
# ## 项目 3: 创建用户分类

# %% [markdown]
# 欢迎来到机器学习工程师纳米学位的第三个项目！在这个notebook文件中，有些模板代码已经提供给你，但你还需要实现更多的功能来完成这个项目。除非有明确要求，你无须修改任何已给出的代码。以**'练习'**开始的标题表示接下来的代码部分中有你必须要实现的功能。每一部分都会有详细的指导，需要实现的部分也会在注释中以**'TODO'**标出。请仔细阅读所有的提示！
#
# 除了实现代码外，你还**必须**回答一些与项目和你的实现有关的问题。每一个需要你回答的问题都会以**'问题 X'**为标题。请仔细阅读每个问题，并且在问题后的**'回答'**文字框中写出完整的答案。我们将根据你对问题的回答和撰写代码所实现的功能来对你提交的项目进行评分。
#
# >**提示：**Code 和 Markdown 区域可通过 **Shift + Enter** 快捷键运行。此外，Markdown可以通过双击进入编辑模式。

# %% [markdown]
# ## 开始
#
# 在这个项目中，你将分析一个数据集的内在结构，这个数据集包含很多客户真对不同类型产品的年度采购额（用**金额**表示）。这个项目的任务之一是如何最好地描述一个批发商不同种类顾客之间的差异。这样做将能够使得批发商能够更好的组织他们的物流服务以满足每个客户的需求。
#
# 这个项目的数据集能够在[UCI机器学习信息库](https://archive.ics.uci.edu/ml/datasets/Wholesale+customers)中找到.因为这个项目的目的，分析将不会包括'Channel'和'Region'这两个特征——重点集中在6个记录的客户购买的产品类别上。
#
# 运行下面的的代码单元以载入整个客户数据集和一些这个项目需要的Python库。如果你的数据集载入成功，你将看到后面输出数据集的大小。

# %%
# 检查你的Python版本
from sys import version_info
if version_info.major != 2 and version_info.minor != 7:
    raise Exception('请使用Python 2.7来完成此项目')

# %%
# 引入这个项目需要的库
import numpy as np
import pandas as pd
import visuals as vs
from IPython.display import display # 使得我们可以对DataFrame使用display()函数

# 设置以内联的形式显示matplotlib绘制的图片（在notebook中显示更美观）
# %matplotlib inline

# 载入整个客户数据集
try:
    data = pd.read_csv("customers.csv")
    data.drop(['Region', 'Channel'], axis = 1, inplace = True)
    y_data = pd.read_csv("customers.csv")
    y_data.drop(['Channel','Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper','Delicatessen'], axis = 1, inplace = True)
    print "Wholesale customers dataset has {} samples with {} features each.".format(*data.shape)
except:
    print "Dataset could not be loaded. Is the dataset missing?"
# Out:
# Wholesale customers dataset has 440 samples with 6 features each.

# %% [markdown]
# ## 分析数据
# 在这部分，你将开始分析数据，通过可视化和代码来理解每一个特征和其他特征的联系。你会看到关于数据集的统计描述，考虑每一个属性的相关性，然后从数据集中选择若干个样本数据点，你将在整个项目中一直跟踪研究这几个数据点。
#
# 运行下面的代码单元给出数据集的一个统计描述。注意这个数据集包含了6个重要的产品类型：**'Fresh'**, **'Milk'**, **'Grocery'**, **'Frozen'**, **'Detergents_Paper'**和 **'Delicatessen'**。想一下这里每一个类型代表你会购买什么样的产品。

# %%
# 显示数据集的一个描述
display(data.describe())
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %% [markdown]
# ### 练习: 选择样本
# 为了对客户有一个更好的了解，并且了解代表他们的数据将会在这个分析过程中如何变换。最好是选择几个样本数据点，并且更为详细地分析它们。在下面的代码单元中，选择**三个**索引加入到索引列表`indices`中，这三个索引代表你要追踪的客户。我们建议你不断尝试，直到找到三个明显不同的客户。

# %%
# TODO：从数据集中选择三个你希望抽样的数据点的索引
#indices = [95,181,154,86,75,85,420,325,75,85,109,183]
indices = [95,75,85]
#print list(data["Delicatessen"]).index(47943)
# 为选择的样本建立一个DataFrame
samples = pd.DataFrame(data.loc[indices], columns = data.keys()).reset_index(drop = True)
print "Chosen samples of wholesale customers dataset:"
display(samples)
# Out:
# Chosen samples of wholesale customers dataset:
#    Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0      3   2920     6252     440               223           709
# 1  20398   1137        3    4407                 3           975
# 2  16117  46197    92780    1026             40827          2944

# %% [markdown]
# ### 问题 1
# *在你看来你选择的这三个样本点分别代表什么类型的企业（客户）？*对每一个你选择的样本客户，通过它在每一种产品类型上的花费与数据集的统计描述进行比较，给出你做上述判断的理由。
#
#
# **提示：** 企业的类型包括超市、咖啡馆、零售商以及其他。注意不要使用具体企业的名字，比如说在描述一个餐饮业客户时，你不能使用麦当劳。

# %% [markdown]
# **回答:**通过找到各项最大值与最小值的所在行，并对比这些数据，我选取Fresh和Grocery两项来做比对判断。Fresh特别少的属于一类，可能是咖啡店，Grocery特别少的也属于一类，可能是零售商，最后是Grocery特别多的属于一类，可能是超市。

# %% [markdown]
# ### 练习: 特征相关性
# 一个有趣的想法是，考虑这六个类别中的一个（或者多个）产品类别，是否对于理解客户的购买行为具有实际的相关性。也就是说，当用户购买了一定数量的某一类产品，我们是否能够确定他们必然会成比例地购买另一种类的产品。有一个简单的方法可以检测相关性：我们用移除了某一个特征之后的数据集来构建一个监督学习（回归）模型，然后用这个模型去预测那个被移除的特征，再对这个预测结果进行评分，来判断由余下5个特征构建的模型对移除掉的那一个特征预测能力的好坏。
#
# 在下面的代码单元中，你需要实现以下的功能：
#  - 使用`DataFrame.drop`函数移除数据集中你选择的不需要的特征，并将移除后的结果赋值给`new_data`。
#  - 使用`sklearn.model_selection.train_test_split`将数据集分割成训练集和测试集。
#    - 使用移除的特征作为你的目标标签。设置`test_size`为`0.25`并设置一个`random_state`。
#  - 导入一个DecisionTreeRegressor（决策树回归器），设置一个`random_state`，然后用训练集训练它。
#  - 使用回归器的`score`函数输出模型在测试集上的预测得分。

# %%
# TODO：为DataFrame创建一个副本，用'drop'函数丢弃一些指定的特征
new_data = data.drop([ 'Grocery', 'Frozen', 'Detergents_Paper','Delicatessen'],axis = 1)

# TODO：使用给定的特征作为目标，将数据分割成训练集和测试集
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_data, y_data, test_size=0.25, random_state=0)

# TODO：创建一个DecisionTreeRegressor（决策树回归器）并在训练集上训练它
from sklearn import tree
regressor = tree.DecisionTreeRegressor()
regressor.fit(new_data, y_data)
# TODO：输出在测试集上的预测得分
score = regressor.score(new_data, y_data)
print score
# Out:
# 1.0

# %% [markdown]
# ### 问题 2
# *你尝试预测哪一个特征？预测的得分是多少？这个特征对于区分用户的消费习惯来说必要吗？*
# **提示：** 决定系数（coefficient of determination）, `R^2`,结果在0到1之间，1表示完美拟合，一个负的`R^2`表示模型不能够拟合数据。

# %% [markdown]
# **回答:**我尝试测试Fresh和Milk，如果只用其中1个，得分只有0.9多些，如果用两个特征，则可以得1.我想这个特征对于区分用户的消费习惯是有必要的。

# %% [markdown]
# ### 可视化特征分布
# 为了能够对这个数据集有一个更好的理解，我们可以对数据集中的每一个产品特征构建一个散布矩阵（scatter matrix）。如果你发现你在上面尝试预测的特征对于区分一个特定的用户来说是必须的，那么这个特征和其它的特征可能不会在下面的散射矩阵中显示任何关系。相反的，如果你认为这个特征对于识别一个特定的客户是没有作用的，那么通过散布矩阵可以看出在这个数据特征和其它特征中有关联性。运行下面的代码以创建一个散布矩阵。

# %%
# 对于数据中的每一对特征构造一个散布矩阵
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %% [markdown]
# ### 问题 3
# *这里是否存在一些特征他们彼此之间存在一定程度相关性？如果有请列出。这个结果是验证了还是否认了你尝试预测的那个特征的相关性？这些特征的数据是怎么分布的？*
#
# **提示：** 这些数据是正态分布(normally distributed)的吗？大多数的数据点分布在哪？

# %% [markdown]
# **回答:**这些数据基本符合正态分布，数据点主要分布在均值附近,但主要只有正态分布的一部分，左侧的一部分并不能看到。可以看到有些数据有比较明显的关联性，比如Grocery和Detergents_Paper和Milk。这个结果验证了我上面选择的特征，我上面选择的是Fresh和Milk。

# %% [markdown]
# ## 数据预处理
# 在这个部分，你将通过在数据上做一个合适的缩放，并检测异常点（你可以选择性移除）将数据预处理成一个更好的代表客户的形式。预处理数据是保证你在分析中能够得到显著且有意义的结果的重要环节。

# %% [markdown]
# ### 练习: 特征缩放
# 如果数据不是正态分布的，尤其是数据的平均数和中位数相差很大的时候（表示数据非常歪斜）。这时候通常用一个非线性的缩放是[很合适的](https://github.com/czcbangkai/translations/blob/master/use_of_logarithms_in_economics/use_of_logarithms_in_economics.pdf)，[（英文原文）](http://econbrowser.com/archives/2014/02/use-of-logarithms-in-economics) — 尤其是对于金融数据。一种实现这个缩放的方法是使用[Box-Cox 变换](http://scipy.github.io/devdocs/generated/scipy.stats.boxcox.html)，这个方法能够计算出能够最佳减小数据倾斜的指数变换方法。一个比较简单的并且在大多数情况下都适用的方法是使用自然对数。
#
# 在下面的代码单元中，你将需要实现以下功能：
#  - 使用`np.log`函数在数据 `data` 上做一个对数缩放，然后将它的副本（不改变原始data的值）赋值给`log_data`。
#  - 使用`np.log`函数在样本数据 `samples` 上做一个对数缩放，然后将它的副本赋值给`log_samples`。

# %%
# TODO：使用自然对数缩放数据
log_data = np.log(data)

# TODO：使用自然对数缩放样本数据
log_samples = np.log(data)

# 为每一对新产生的特征制作一个散射矩阵
pd.plotting.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %% [markdown]
# ### 观察
# 在使用了一个自然对数的缩放之后，数据的各个特征会显得更加的正态分布。对于任意的你以前发现有相关关系的特征对，观察他们的相关关系是否还是存在的（并且尝试观察，他们的相关关系相比原来是变强了还是变弱了）。
#
# 运行下面的代码以观察样本数据在进行了自然对数转换之后如何改变了。

# %%
# 展示经过对数变换后的样本数据
display(log_samples)
# Out:
#          Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicatessen
# 0     9.446913   9.175335   8.930759  5.365976          7.891331      7.198931
# 1     8.861775   9.191158   9.166179  7.474205          8.099554      7.482119
# 2     8.756682   9.083416   8.946896  7.785305          8.165079      8.967504
# 3     9.492884   7.086738   8.347827  8.764678          6.228511      7.488853
# 4    10.026369   8.596004   8.881558  8.272571          7.482682      8.553525
# 5     9.149847   9.019059   8.542081  6.501290          7.492760      7.280008
# 6     9.403107   8.070594   8.850088  6.173786          8.051978      6.300786
# 7     8.933137   8.508354   9.151227  7.419980          8.108021      7.850104
# 8     8.693329   8.201934   8.731013  6.052089          7.447751      6.620073
# 9     8.700514   9.314070   9.845911  7.055313          8.912608      7.648740
# 10    8.121480   8.594710   9.470703  8.389360          8.695674      7.463937
# 11    9.483873   7.024649   8.416931  7.258412          6.308098      6.208590
# 12   10.364514   9.418898   9.372204  5.659482          8.263848      7.983099
# 13    9.962558   8.733594   9.614605  8.037543          8.810907      6.400257
# 14   10.112654   9.155356   9.400217  5.683580          8.528726      7.681560
# 15    9.235326   7.015712   8.248267  5.983936          6.871091      6.021023
# 16    6.927558   9.084324   9.402695  4.897840          8.413609      6.984716
# 17    8.678632   8.725345   7.983781  6.732211          5.913503      8.406932
# 18    9.830971   8.752581   9.220192  7.698483          7.925519      8.064951
# 19    8.959312   7.822044   9.155250  6.505784          7.831220      6.216606
# 20    9.772581   8.416046   8.434246  6.971669          7.722678      7.661056
# 21    8.624612   6.769642   7.605890  8.126518          5.926926      6.343880
# 22   10.350606   7.558517   8.404920  9.149316          7.775276      8.374246
# 23   10.180096  10.502956   9.999661  8.547528          8.374938      9.712509
# 24   10.027783   9.187686   9.531844  7.977625          8.407825      8.661813
# 25    9.690604   8.349957   8.935245  5.303305          8.294799      4.043051
# 26    9.200088   6.867974   7.958926  8.055475          5.488938      6.725034
# 27    9.566335   6.688355   8.021256  6.184149          4.605170      6.249975
# 28    8.321908   9.927399  10.164197  7.054450          9.059982      8.557567
# 29   10.671000   7.649693   7.866722  7.090077          7.009409      6.712956
# ..         ...        ...        ...       ...               ...           ...
# 410   8.799812   7.647786   8.425736  7.236339          7.528332      7.545390
# 411   7.661998   8.098339   8.095904  7.336286          5.459586      8.381373
# 412   4.574711   8.190077   9.425452  4.584967          7.996317      4.127134
# 413   8.513787   8.488588   8.799812  9.790655          6.815640      7.797702
# 414   8.694335   7.595890   8.136518  8.644530          7.034388      5.669881
# 415   8.967249   8.707152   9.053920  7.433075          8.171882      7.535830
# 416   8.386857   9.300181   9.297252  6.742881          8.814033      6.900731
# 417   8.530109   8.612322   9.310638  5.897154          8.156223      6.968850
# 418   6.492240   9.047115   9.832099  4.890349          8.815815      6.654153
# 419   9.089415   8.238273   7.706613  6.450470          7.365180      7.327123
# 420   8.402007   8.569026   9.490015  3.218876          8.827321      7.239215
# 421   9.744668   8.486115   9.110851  6.938284          8.135933      7.486613
# 422  10.181119   7.227662   8.336151  6.721426          6.854355      7.104965
# 423   9.773664   8.212297   8.446127  6.965080          7.497207      6.504288
# 424   9.739791   7.966933   9.411811  6.773080          8.074960      5.517453
# 425   9.327501   7.786552   7.860571  9.638740          4.682131      7.542213
# 426   9.482960   9.142811   9.569133  8.052296          8.532870      7.546446
# 427  10.342130   9.722385   8.599510  9.621257          6.084499      7.058758
# 428   8.021913   8.694502   8.499029  7.695303          6.745236      5.758902
# 429   9.060331   7.467371   8.183118  3.850148          4.430817      7.824446
# 430   8.038189   8.349957   9.710085  6.354370          5.484797      7.640123
# 431   9.051696   8.613594   8.548692  9.509407          7.227662      7.311886
# 432   9.957834   7.057898   8.466742  5.594711          7.191429      5.978886
# 433   7.591862   8.076515   7.308543  7.340187          5.874931      7.278629
# 434   9.725019   8.274357   8.986447  6.533789          7.771067      6.731018
# 435  10.299003   9.396903   9.682030  9.483036          5.204007      7.698029
# 436  10.577146   7.266129   6.638568  8.414052          4.532599      7.760467
# 437   9.584040   9.647821  10.317020  6.079933          9.605149      7.532088
# 438   9.238928   7.591357   7.710653  6.945051          5.123964      7.661527
# 439   7.932721   7.437206   7.828038  4.174387          6.167516      3.951244
#
# [440 rows x 6 columns]

# %% [markdown]
# ### 练习: 异常值检测
# 对于任何的分析，在数据预处理的过程中检测数据中的异常值都是非常重要的一步。异常值的出现会使得把这些值考虑进去后结果出现倾斜。这里有很多关于怎样定义什么是数据集中的异常值的经验法则。这里我们将使用[Tukey的定义异常值的方法](http://datapigtechnologies.com/blog/index.php/highlighting-outliers-in-your-data-with-the-tukey-method/)：一个*异常阶（outlier step）*被定义成1.5倍的四分位距（interquartile range，IQR）。一个数据点如果某个特征包含在该特征的IQR之外的特征，那么该数据点被认定为异常点。
#
# 在下面的代码单元中，你需要完成下面的功能：
#  - 将指定特征的25th分位点的值分配给`Q1`。使用`np.percentile`来完成这个功能。
#  - 将指定特征的75th分位点的值分配给`Q3`。同样的，使用`np.percentile`来完成这个功能。
#  - 将指定特征的异常阶的计算结果赋值给`step`.
#  - 选择性地通过将索引添加到`outliers`列表中，以移除异常值。
#
# **注意：** 如果你选择移除异常值，请保证你选择的样本点不在这些移除的点当中！
# 一旦你完成了这些功能，数据集将存储在`good_data`中。

# %%
# 对于每一个特征，找到值异常高或者是异常低的数据点
for feature in log_data.keys():
    
    # TODO：计算给定特征的Q1（数据的25th分位点）
    Q1 = np.percentile(log_data[feature],25)
    
    # TODO：计算给定特征的Q3（数据的75th分位点）
    Q3 = np.percentile(log_data[feature],75)
    
    # TODO：使用四分位范围计算异常阶（1.5倍的四分位距）
    step = (Q3-Q1)*1.5
    #print Q1
    #print Q3
    #print step
    # 显示异常点
    print "Data points considered outliers for the feature '{}':".format(feature)
    display(log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))])
    
# 可选：选择你希望移除的数据点的索引
outliers  = []

# 如果选择了的话，移除异常点
good_data = log_data.drop(log_data.index[outliers]).reset_index(drop = True)
# Out:
# Data points considered outliers for the feature 'Fresh':
#         Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicatessen
# 65   4.442651   9.950323  10.732651  3.583519         10.095388      7.260523
# 66   2.197225   7.335634   8.911530  5.164786          8.151333      3.295837
# 81   5.389072   9.163249   9.575192  5.645447          8.964184      5.049856
# 95   1.098612   7.979339   8.740657  6.086775          5.407172      6.563856
# 96   3.135494   7.869402   9.001839  4.976734          8.262043      5.379897
# 128  4.941642   9.087834   8.248791  4.955827          6.967909      1.098612
# 171  5.298317  10.160530   9.894245  6.478510          9.079434      8.740337
# 193  5.192957   8.156223   9.917982  6.865891          8.633731      6.501290
# 218  2.890372   8.923191   9.629380  7.158514          8.475746      8.759669
# 304  5.081404   8.917311  10.117510  6.424869          9.374413      7.787382
# 305  5.493061   9.468001   9.088399  6.683361          8.271037      5.351858
# 338  1.098612   5.808142   8.856661  9.655090          2.708050      6.309918
# 353  4.762174   8.742574   9.961898  5.429346          9.069007      7.013016
# 355  5.247024   6.588926   7.606885  5.501258          5.214936      4.844187
# 357  3.610918   7.150701  10.011086  4.919981          8.816853      4.700480
# 412  4.574711   8.190077   9.425452  4.584967          7.996317      4.127134
# Data points considered outliers for the feature 'Milk':
#          Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicatessen
# 86   10.039983  11.205013  10.377047  6.894670          9.906981      6.805723
# 98    6.220590   4.718499   6.656727  6.796824          4.025352      4.882802
# 154   6.432940   4.007333   4.919981  4.317488          1.945910      2.079442
# 356  10.029503   4.897840   5.384495  8.057377          2.197225      6.306275
# Data points considered outliers for the feature 'Grocery':
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 75   9.923192  7.036148  1.098612  8.390949          1.098612      6.882437
# 154  6.432940  4.007333  4.919981  4.317488          1.945910      2.079442
# Data points considered outliers for the feature 'Frozen':
#          Fresh      Milk    Grocery     Frozen  Detergents_Paper  Delicatessen
# 38    8.431853  9.663261   9.723703   3.496508          8.847360      6.070738
# 57    8.597297  9.203618   9.257892   3.637586          8.932213      7.156177
# 65    4.442651  9.950323  10.732651   3.583519         10.095388      7.260523
# 145  10.000569  9.034080  10.457143   3.737670          9.440738      8.396155
# 175   7.759187  8.967632   9.382106   3.951244          8.341887      7.436617
# 264   6.978214  9.177714   9.645041   4.110874          8.696176      7.142827
# 325  10.395650  9.728181   9.519735  11.016479          7.148346      8.632128
# 420   8.402007  8.569026   9.490015   3.218876          8.827321      7.239215
# 429   9.060331  7.467371   8.183118   3.850148          4.430817      7.824446
# 439   7.932721  7.437206   7.828038   4.174387          6.167516      3.951244
# Data points considered outliers for the feature 'Detergents_Paper':
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 75   9.923192  7.036148  1.098612  8.390949          1.098612      6.882437
# 161  9.428190  6.291569  5.645447  6.995766          1.098612      7.711101
# Data points considered outliers for the feature 'Delicatessen':
#          Fresh       Milk    Grocery     Frozen  Detergents_Paper  \
# 66    2.197225   7.335634   8.911530   5.164786          8.151333
# 109   7.248504   9.724899  10.274568   6.511745          6.728629
# 128   4.941642   9.087834   8.248791   4.955827          6.967909
# 137   8.034955   8.997147   9.021840   6.493754          6.580639
# 142  10.519646   8.875147   9.018332   8.004700          2.995732
# 154   6.432940   4.007333   4.919981   4.317488          1.945910
# 183  10.514529  10.690808   9.911952  10.505999          5.476464
# 184   5.789960   6.822197   8.457443   4.304065          5.811141
# 187   7.798933   8.987447   9.192075   8.743372          8.148735
# 203   6.368187   6.529419   7.703459   6.150603          6.860664
# 233   6.871091   8.513988   8.106515   6.842683          6.013715
# 285  10.602965   6.461468   8.188689   6.948897          6.077642
# 289  10.663966   5.655992   6.154858   7.235619          3.465736
# 343   7.431892   8.848509  10.177932   7.283448          9.646593
#
#      Delicatessen
# 66       3.295837
# 109      1.098612
# 128      1.098612
# 137      3.583519
# 142      1.098612
# 154      2.079442
# 183     10.777768
# 184      2.397895
# 187      1.098612
# 203      2.890372
# 233      1.945910
# 285      2.890372
# 289      3.091042
# 343      3.610918

# %% [markdown]
# ### 问题 4
# *请列出所有在多于一个特征下被看作是异常的数据点。这些点应该被从数据集中移除吗？为什么？把你认为需要移除的数据点全部加入到到`outliers`变量中。*

# %% [markdown]
# **回答:**比如154，在Milk，Grocery，Delicatessen都出现异常。但因为这三个数据是关联的，所以我并不认为一定要除移这个数据点。经过log之后的数据看不太出来异常，所以我并没有加入异常数据。

# %% [markdown]
# ## 特征转换
# 在这个部分中你将使用主成分分析（PCA）来分析批发商客户数据的内在结构。由于使用PCA在一个数据集上会计算出最大化方差的维度，我们将找出哪一个特征组合能够最好的描绘客户。

# %% [markdown]
# ### 练习: 主成分分析（PCA）
#
# 既然数据被缩放到一个更加正态分布的范围中并且我们也移除了需要移除的异常点，我们现在就能够在`good_data`上使用PCA算法以发现数据的哪一个维度能够最大化特征的方差。除了找到这些维度，PCA也将报告每一个维度的*解释方差比（explained variance ratio）*--这个数据有多少方差能够用这个单独的维度来解释。注意PCA的一个组成部分（维度）能够被看做这个空间中的一个新的“特征”，但是它是原来数据中的特征构成的。
#
# 在下面的代码单元中，你将要实现下面的功能：
#  - 导入`sklearn.decomposition.PCA`并且将`good_data`用PCA并且使用6个维度进行拟合后的结果保存到`pca`中。
#  - 使用`pca.transform`将`log_samples`进行转换，并将结果存储到`pca_samples`中。

# %%
# TODO：通过在good data上使用PCA，将其转换成和当前特征数一样多的维度
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(log_samples)
# TODO：使用上面的PCA拟合将变换施加在log_samples上
pca_samples = pca.transform(log_samples)

# 生成PCA的结果图
pca_results = vs.pca_results(good_data, pca)

# %% [markdown]
# ### 问题 5
# *数据的第一个和第二个主成分* **总共** *表示了多少的方差？*  前四个主成分呢？使用上面提供的可视化图像，讨论从用户花费的角度来看前四个**主要成分**的消费行为最能代表哪种类型的客户并给出你做出判断的理由。
#
# **提示：** 某一特定维度上的正向增长对应**正权**特征的**增长**和**负权**特征的**减少**。增长和减少的速率和每个特征的权重相关。[参考资料(英文)](https://onlinecourses.science.psu.edu/stat505/node/54)。

# %% [markdown]
# **回答:**第一个和第二个主成分总共表示了6个方差。前四个的话同样是6个，因为重复了。第一个主成分的Milk，Grocery，以及Detergents_Pater的权重特别高，我觉得可以代表

# %% [markdown]
# ### 观察
# 运行下面的代码，查看经过对数转换的样本数据在进行一个6个维度的主成分分析（PCA）之后会如何改变。观察样本数据的前四个维度的数值。考虑这和你初始对样本点的解释是否一致。

# %%
# 展示经过PCA转换的sample log-data
#print pca_samples
display(pd.DataFrame(np.round(pca_samples, 4), columns = pca_results.index.values))
# Out:
#      Dimension 1  Dimension 2  Dimension 3  Dimension 4  Dimension 5  \
# 0        -1.7510      -0.0705      -0.9118      -1.7265       0.2741
# 1        -1.8004      -0.8698       0.2128       0.0079       0.1188
# 2        -1.8937      -1.6766       1.3189      -0.4852      -0.3736
# 3         1.1273      -1.4580       0.5247       0.4620      -0.6799
# 4        -0.7967      -2.4609       0.4706      -0.2949      -0.3016
# 5        -1.0838      -0.3929      -0.2417      -0.8931       0.1939
# 6        -1.1326       0.2016      -1.3001      -0.6000      -0.4962
# 7        -1.5825      -0.9682       0.3626      -0.2521      -0.4543
# 8        -0.8718       0.5968      -0.5109      -0.8300      -0.1596
# 9        -2.8889      -0.7411       0.1143      -0.1801      -0.0314
# 10       -2.1162      -0.7488       0.8007       1.0355      -0.5710
# 11        0.9915      -0.0627      -0.7451      -0.0744      -0.4409
# 12       -2.2326      -1.3278      -1.0282      -1.9855       0.2291
# 13       -1.9040      -1.3339      -1.2503       0.9372      -0.2665
# 14       -2.3334      -0.9836      -1.1135      -1.7100      -0.0426
# 15        0.4173       0.8143      -1.1793      -0.8562      -0.7403
# 16       -2.8051       1.9532       0.3815      -1.3259       0.1391
# 17        0.2526      -0.6045       1.2207      -1.5262       0.4495
# 18       -1.4023      -1.8655       0.0214      -0.3560      -0.2039
# 19       -1.0160       0.4151      -0.9308      -0.2209      -0.4404
# 20       -0.8361      -1.1474      -0.3482      -0.8175      -0.5008
# 21        1.7247       0.1473       0.2689       0.6106      -0.7496
# 22       -0.1549      -2.8299       0.3035       0.4400      -1.3788
# 23       -2.8213      -3.7157       1.0248      -0.4243       0.7254
# 24       -2.0820      -2.5532       0.2522      -0.3598      -0.1799
# 25       -1.2251       1.5185      -3.2435      -0.1471       0.0707
# 26        1.8828      -0.4287       0.1943       0.1756      -0.3812
# 27        2.3966       0.5371      -0.7066      -1.3347       0.1692
# 28       -3.5870      -1.0724       0.9327      -0.5064       0.2621
# 29        0.5739      -1.1438      -1.3821      -0.6141      -0.6696
# ..           ...          ...          ...          ...          ...
# 410      -0.4905      -0.4176       0.3251      -0.3880      -0.9353
# 411       0.7186      -0.0765       2.1357      -0.8989       0.2754
# 412      -2.1872       5.3355       0.0958       0.2991       0.3079
# 413      -0.1083      -1.7286       1.5791       1.5070       0.0622
# 414       0.5341      -0.0269      -0.2964       1.6193      -0.4796
# 415      -1.6091      -0.8660       0.1365      -0.0779      -0.3197
# 416      -2.5571       0.0519      -0.2069      -0.0350      -0.0191
# 417      -1.9324       0.4698      -0.3800      -0.9193      -0.1232
# 418      -3.3129       2.3830       0.3566      -0.9655       0.1001
# 419      -0.3274      -0.1607      -0.1562      -1.0379      -0.5962
# 420      -3.0210       1.6924      -1.0359      -3.0513      -0.4260
# 421      -1.4638      -1.0988      -0.5610      -0.6254      -0.4124
# 422       0.4355      -0.7857      -0.8997      -1.0146      -0.7865
# 423      -0.4212      -0.5136      -1.0544      -0.2749      -0.2905
# 424      -1.0853       0.0548      -1.8876       0.2519      -0.2576
# 425       2.3393      -1.8132       1.2958       0.8623       0.4857
# 426      -2.0896      -1.6483      -0.1086       0.4152      -0.0541
# 427       0.4400      -2.6778       0.0300       1.2291       1.4448
# 428      -0.1420       0.6599       0.0313       0.9414       0.6206
# 429       1.4207       1.0891       0.0429      -3.9243       0.6639
# 430      -0.1258       0.3686       1.0758      -1.2769       1.1848
# 431      -0.2331      -1.7325       0.7459       1.4789      -0.0624
# 432       0.1273       0.4951      -1.8795      -1.2274      -0.7926
# 433       0.9286       0.5725       1.4072      -0.2867      -0.0331
# 434      -1.0119      -0.4446      -1.0734      -0.6405      -0.2406
# 435       0.6061      -2.8920       0.5783       0.6951       1.9629
# 436       3.1849      -2.0078       0.3008      -0.6217      -0.2305
# 437      -3.7479      -0.9272      -0.9890      -0.9276       0.0407
# 438       1.6580      -0.4760       0.5671      -1.2806       0.1178
# 439       0.7379       3.6344      -1.9705      -1.1258       0.2855
#
#      Dimension 6
# 0         0.3984
# 1         0.2314
# 2         0.3284
# 3        -0.6652
# 4        -0.0575
# 5         0.5362
# 6        -0.0956
# 7        -0.1350
# 8        -0.0341
# 9        -0.0822
# 10       -0.2135
# 11       -0.6833
# 12        0.1969
# 13       -0.2554
# 14        0.0985
# 15       -0.4031
# 16        0.1574
# 17        0.4955
# 18       -0.1315
# 19       -0.5145
# 20        0.3080
# 21       -0.2319
# 22       -0.1944
# 23        0.2129
# 24       -0.0755
# 25        0.0942
# 26       -0.5788
# 27       -0.8732
# 28        0.0119
# 29        0.2026
# ..           ...
# 410      -0.1151
# 411      -0.0083
# 412      -0.2916
# 413      -0.1493
# 414       0.0134
# 415       0.0710
# 416       0.3685
# 417      -0.1401
# 418      -0.1104
# 419       0.7680
# 420      -0.1294
# 421      -0.1156
# 422      -0.4282
# 423       0.1685
# 424      -0.6069
# 425      -0.2133
# 426      -0.0648
# 427       0.5021
# 428       0.2906
# 429      -0.5976
# 430      -1.1574
# 431       0.2067
# 432      -0.5065
# 433       0.7319
# 434      -0.1784
# 435      -0.7449
# 436       0.4482
# 437      -0.1504
# 438      -0.0609
# 439       0.1424
#
# [440 rows x 6 columns]

# %% [markdown]
# ### 练习：降维
# 当使用主成分分析的时候，一个主要的目的是减少数据的维度，这实际上降低了问题的复杂度。当然降维也是需要一定代价的：更少的维度能够表示的数据中的总方差更少。因为这个，*累计解释方差比（cumulative explained variance ratio）*对于我们确定这个问题需要多少维度非常重要。另外，如果大部分的方差都能够通过两个或者是三个维度进行表示的话，降维之后的数据能够被可视化。
#
# 在下面的代码单元中，你将实现下面的功能：
#  - 将`good_data`用两个维度的PCA进行拟合，并将结果存储到`pca`中去。
#  - 使用`pca.transform`将`good_data`进行转换，并将结果存储在`reduced_data`中。
#  - 使用`pca.transform`将`log_samples`进行转换，并将结果存储在`pca_samples`中。

# %%
# TODO：通过在good data上进行PCA，将其转换成两个维度
pca = PCA(n_components=2)
pca.fit(good_data)
# TODO：使用上面训练的PCA将good data进行转换
reduced_data = pca.transform(good_data)

# TODO：使用上面训练的PCA将log_samples进行转换
pca_samples = pca.transform(log_samples)

# 为降维后的数据创建一个DataFrame
reduced_data = pd.DataFrame(reduced_data, columns = ['Dimension 1', 'Dimension 2'])

# %% [markdown]
# ### 观察
# 运行以下代码观察当仅仅使用两个维度进行PCA转换后，这个对数样本数据将怎样变化。观察这里的结果与一个使用六个维度的PCA转换相比较时，前两维的数值是保持不变的。

# %%
# 展示经过两个维度的PCA转换之后的样本log-data
display(pd.DataFrame(np.round(pca_samples, 4), columns = ['Dimension 1', 'Dimension 2']))
# Out:
#      Dimension 1  Dimension 2
# 0        -1.7510      -0.0705
# 1        -1.8004      -0.8698
# 2        -1.8937      -1.6766
# 3         1.1273      -1.4580
# 4        -0.7967      -2.4609
# 5        -1.0838      -0.3929
# 6        -1.1326       0.2016
# 7        -1.5825      -0.9682
# 8        -0.8718       0.5968
# 9        -2.8889      -0.7411
# 10       -2.1162      -0.7488
# 11        0.9915      -0.0627
# 12       -2.2326      -1.3278
# 13       -1.9040      -1.3339
# 14       -2.3334      -0.9836
# 15        0.4173       0.8143
# 16       -2.8051       1.9532
# 17        0.2526      -0.6045
# 18       -1.4023      -1.8655
# 19       -1.0160       0.4151
# 20       -0.8361      -1.1474
# 21        1.7247       0.1473
# 22       -0.1549      -2.8299
# 23       -2.8213      -3.7157
# 24       -2.0820      -2.5532
# 25       -1.2251       1.5185
# 26        1.8828      -0.4287
# 27        2.3966       0.5371
# 28       -3.5870      -1.0724
# 29        0.5739      -1.1438
# ..           ...          ...
# 410      -0.4905      -0.4176
# 411       0.7186      -0.0765
# 412      -2.1872       5.3355
# 413      -0.1083      -1.7286
# 414       0.5341      -0.0269
# 415      -1.6091      -0.8660
# 416      -2.5571       0.0519
# 417      -1.9324       0.4698
# 418      -3.3129       2.3830
# 419      -0.3274      -0.1607
# 420      -3.0210       1.6924
# 421      -1.4638      -1.0988
# 422       0.4355      -0.7857
# 423      -0.4212      -0.5136
# 424      -1.0853       0.0548
# 425       2.3393      -1.8132
# 426      -2.0896      -1.6483
# 427       0.4400      -2.6778
# 428      -0.1420       0.6599
# 429       1.4207       1.0891
# 430      -0.1258       0.3686
# 431      -0.2331      -1.7325
# 432       0.1273       0.4951
# 433       0.9286       0.5725
# 434      -1.0119      -0.4446
# 435       0.6061      -2.8920
# 436       3.1849      -2.0078
# 437      -3.7479      -0.9272
# 438       1.6580      -0.4760
# 439       0.7379       3.6344
#
# [440 rows x 2 columns]

# %% [markdown]
# ## 可视化一个双标图（Biplot）
# 双标图是一个散点图，每个数据点的位置由它所在主成分的分数确定。坐标系是主成分（这里是`Dimension 1` 和 `Dimension 2`）。此外，双标图还展示出初始特征在主成分上的投影。一个双标图可以帮助我们理解降维后的数据，发现主成分和初始特征之间的关系。
#
# 运行下面的代码来创建一个降维后数据的双标图。

# %%
# Create a biplot
vs.biplot(good_data, reduced_data, pca)

# %% [markdown]
# ### 观察
#
# 一旦我们有了原始特征的投影（红色箭头），就能更加容易的理解散点图每个数据点的相对位置。
#
# 在这个双标图中，哪些初始特征与第一个主成分有强关联？哪些初始特征与第二个主成分相关联？你观察到的是否与之前得到的 pca_results 图相符？

# %% [markdown]
# ## 聚类
#
# 在这个部分，你讲选择使用K-Means聚类算法或者是高斯混合模型聚类算法以发现数据中隐藏的客户分类。然后，你将从簇中恢复一些特定的关键数据点，通过将它们转换回原始的维度和规模，从而理解他们的含义。

# %% [markdown]
# ### 问题 6
# *使用K-Means聚类算法的优点是什么？使用高斯混合模型聚类算法的优点是什么？基于你现在对客户数据的观察结果，你选用了这两个算法中的哪一个，为什么？*

# %% [markdown]
# **回答:** K-Means：算法简单，容易理解。计算量不大，收敛快。可以很方便的进行分布式计算。默认所有属性对距离的影响是相同的，默认所有数据均匀分布在聚类中。如果数据是三维空间中的圆柱体，模型就失效了。 高斯混合模型：假设各个特征的权重不同，假设各个聚类中的数据分布不均匀。理论上可以拟合任何连续函数。计算量较大。如果其中一个聚类的数据并不服从正态分布、偏态分布，聚类算法会出现偏差。
#     基于我现在对客户数据的观察结果，基本符合正态分布，所以选择高斯混合模型。

# %% [markdown]
# ### 练习: 创建聚类
#
# 针对不同情况，有些问题你需要的聚类数目可能是已知的。但是在聚类数目不作为一个**先验**知道的情况下，我们并不能够保证某个聚类的数目对这个数据是最优的，因为我们对于数据的结构（如果存在的话）是不清楚的。但是，我们可以通过计算每一个簇中点的**轮廓系数**来衡量聚类的质量。数据点的[轮廓系数](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html)衡量了它与分配给他的簇的相似度，这个值范围在-1（不相似）到1（相似）。**平均**轮廓系数为我们提供了一种简单地度量聚类质量的方法。
#
# 在接下来的代码单元中，你将实现下列功能：
#  - 在`reduced_data`上使用一个聚类算法，并将结果赋值到`clusterer`，需要设置 `random_state` 使得结果可以复现。
#  - 使用`clusterer.predict`预测`reduced_data`中的每一个点的簇，并将结果赋值到`preds`。
#  - 使用算法的某个属性值找到聚类中心，并将它们赋值到`centers`。
#  - 预测`pca_samples`中的每一个样本点的类别并将结果赋值到`sample_preds`。
#  - 导入sklearn.metrics.silhouette_score包并计算`reduced_data`相对于`preds`的轮廓系数。
#    - 将轮廓系数赋值给`score`并输出结果。

# %%
# TODO：在降维后的数据上使用你选择的聚类算法
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
clusterer = GaussianMixture(n_components=3)

# TODO：预测每一个点的簇
clusterer.fit(reduced_data)
preds = clusterer.predict(reduced_data)

# TODO：找到聚类中心
centers = clusterer.means_ 

# TODO：预测在每一个转换后的样本点的类
sample_preds = clusterer.predict_proba(pca_samples)
#print reduced_data
#print preds
# TODO：计算选择的类别的平均轮廓系数（mean silhouette coefficient）
score = silhouette_score(reduced_data,preds)
print score
# Out:
# 0.424101248951

# %% [markdown]
# ### 问题 7
#
# *汇报你尝试的不同的聚类数对应的轮廓系数。在这些当中哪一个聚类的数目能够得到最佳的轮廓系数？*

# %% [markdown]
# **回答:**当数目为3的时候，有最佳的轮廓系数。

# %% [markdown]
# ### 聚类可视化
# 一旦你选好了通过上面的评价函数得到的算法的最佳聚类数目，你就能够通过使用下面的代码块可视化来得到的结果。作为实验，你可以试着调整你的聚类算法的聚类的数量来看一下不同的可视化结果。但是你提供的最终的可视化图像必须和你选择的最优聚类数目一致。

# %%
# 从已有的实现中展示聚类的结果
vs.cluster_results(reduced_data, preds, centers, pca_samples)

# %% [markdown]
# ### 练习: 数据恢复
# 上面的可视化图像中提供的每一个聚类都有一个中心点。这些中心（或者叫平均点）并不是数据中真实存在的点，但是是所有预测在这个簇中的数据点的*平均*。对于创建客户分类的问题，一个簇的中心对应于*那个分类的平均用户*。因为这个数据现在进行了降维并缩放到一定的范围，我们可以通过施加一个反向的转换恢复这个点所代表的用户的花费。
#
# 在下面的代码单元中，你将实现下列的功能：
#  - 使用`pca.inverse_transform`将`centers` 反向转换，并将结果存储在`log_centers`中。
#  - 使用`np.log`的反函数`np.exp`反向转换`log_centers`并将结果存储到`true_centers`中。

# %%
# TODO：反向转换中心点
log_centers = pca.inverse_transform(centers)

# TODO：对中心点做指数转换
true_centers = np.exp(log_centers)

# 显示真实的中心点
segments = ['Segment {}'.format(i) for i in range(0,len(centers))]
true_centers = pd.DataFrame(np.round(true_centers), columns = data.keys())
true_centers.index = segments
display(true_centers)
# Out:
#             Fresh    Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# Segment 0  1902.0  1781.0   2795.0   666.0             444.0         260.0
# Segment 1  4665.0  8067.0  12488.0  1091.0            4460.0        1161.0
# Segment 2  9712.0  2162.0   2676.0  2172.0             351.0         772.0

# %% [markdown]
# ### 问题 8
# 考虑上面的代表性数据点在每一个产品类型的花费总数，*你认为这些客户分类代表了哪类客户？为什么？*需要参考在项目最开始得到的统计值来给出理由。
#
# **提示：** 一个被分到`'Cluster X'`的客户最好被用 `'Segment X'`中的特征集来标识的企业类型表示。

# %% [markdown]
# **回答:**因为这个涉及地域的消费习惯，并且涉及没种类产品的俗称类别，所以我只能大致猜测 Cluster 0 是零售店，因为Grocery最多。Cluster 1是超市，因为量都很大。Cluster 2 是饭店，因为Fresh需求最多。

# %% [markdown]
# ### 问题 9
# *对于每一个样本点 * **问题 8**  *中的哪一个分类能够最好的表示它？你之前对样本的预测和现在的结果相符吗？*
#
# 运行下面的代码单元以找到每一个样本点被预测到哪一个簇中去。

# %%
# 显示预测结果
for i, pred in enumerate(sample_preds):
    print "Sample point", i, "predicted to be in Cluster", pred
# Out:
# Sample point 0 predicted to be in Cluster [ 0.03763109  0.9073977   0.05497122]
# Sample point 1 predicted to be in Cluster [ 0.02865411  0.9024171   0.0689288 ]
# Sample point 2 predicted to be in Cluster [ 0.02539137  0.91030686  0.06430177]
# Sample point 3 predicted to be in Cluster [ 0.02508997  0.01225733  0.9626527 ]
# Sample point 4 predicted to be in Cluster [ 0.03758768  0.5911073   0.37130501]
# Sample point 5 predicted to be in Cluster [ 0.04381845  0.68205584  0.27412571]
# Sample point 6 predicted to be in Cluster [ 0.05859442  0.73797881  0.20342677]
# Sample point 7 predicted to be in Cluster [ 0.03034332  0.85539357  0.11426311]
# Sample point 8 predicted to be in Cluster [ 0.08480079  0.62888766  0.28631155]
# Sample point 9 predicted to be in Cluster [ 0.02595234  0.96928786  0.0047598 ]
# Sample point 10 predicted to be in Cluster [ 0.02673532  0.94173597  0.03152871]
# Sample point 11 predicted to be in Cluster [ 0.02963585  0.01030832  0.96005584]
# Sample point 12 predicted to be in Cluster [ 0.02412933  0.94667771  0.02919296]
# Sample point 13 predicted to be in Cluster [ 0.02579758  0.91341253  0.06078989]
# Sample point 14 predicted to be in Cluster [ 0.02467572  0.9546298   0.02069448]
# Sample point 15 predicted to be in Cluster [ 0.07515628  0.0525253   0.87231842]
# Sample point 16 predicted to be in Cluster [  8.26990550e-02   9.17011091e-01   2.89853795e-04]
# Sample point 17 predicted to be in Cluster [ 0.03026233  0.07087614  0.89886153]
# Sample point 18 predicted to be in Cluster [ 0.02933187  0.80255596  0.16811217]
# Sample point 19 predicted to be in Cluster [ 0.07049679  0.69470442  0.23479879]
# Sample point 20 predicted to be in Cluster [ 0.03551327  0.52846656  0.43602018]
# Sample point 21 predicted to be in Cluster [ 0.03288961  0.00136051  0.96574988]
# Sample point 22 predicted to be in Cluster [ 0.04972044  0.33850461  0.61177496]
# Sample point 23 predicted to be in Cluster [ 0.04539694  0.94773531  0.00686774]
# Sample point 24 predicted to be in Cluster [ 0.02683711  0.93260673  0.04055616]
# Sample point 25 predicted to be in Cluster [ 0.13678996  0.80256167  0.06064837]
# Sample point 26 predicted to be in Cluster [ 0.02818808  0.00108173  0.97073019]
# Sample point 27 predicted to be in Cluster [  5.29069034e-02   1.85275105e-04   9.46907822e-01]
# Sample point 28 predicted to be in Cluster [ 0.03395918  0.96496006  0.00108076]
# Sample point 29 predicted to be in Cluster [ 0.02488408  0.03799377  0.93712216]
# Sample point 30 predicted to be in Cluster [ 0.0324228   0.68788133  0.27969586]
# Sample point 31 predicted to be in Cluster [ 0.05791895  0.13156741  0.81051364]
# Sample point 32 predicted to be in Cluster [ 0.05107335  0.03181991  0.91710675]
# Sample point 33 predicted to be in Cluster [ 0.03054196  0.03675082  0.93270722]
# Sample point 34 predicted to be in Cluster [ 0.31980204  0.04147105  0.63872691]
# Sample point 35 predicted to be in Cluster [ 0.09522457  0.90227968  0.00249575]
# Sample point 36 predicted to be in Cluster [ 0.03523544  0.23044605  0.73431851]
# Sample point 37 predicted to be in Cluster [ 0.02512217  0.94423703  0.0306408 ]
# Sample point 38 predicted to be in Cluster [  8.45376807e-02   9.15408165e-01   5.41539295e-05]
# Sample point 39 predicted to be in Cluster [  2.36944912e-01   5.21549375e-04   7.62533539e-01]
# Sample point 40 predicted to be in Cluster [ 0.05338894  0.3075086   0.63910247]
# Sample point 41 predicted to be in Cluster [ 0.03372615  0.53014164  0.4361322 ]
# Sample point 42 predicted to be in Cluster [ 0.08528184  0.91232815  0.00239002]
# Sample point 43 predicted to be in Cluster [  1.40949937e-01   8.59024511e-01   2.55521005e-05]
# Sample point 44 predicted to be in Cluster [ 0.08196593  0.88976157  0.02827249]
# Sample point 45 predicted to be in Cluster [ 0.02897376  0.96843256  0.00259368]
# Sample point 46 predicted to be in Cluster [ 0.02847874  0.9687308   0.00279046]
# Sample point 47 predicted to be in Cluster [  1.94586722e-01   8.05025959e-01   3.87318886e-04]
# Sample point 48 predicted to be in Cluster [ 0.02848159  0.94054194  0.03097647]
# Sample point 49 predicted to be in Cluster [  3.62195269e-02   9.63110325e-01   6.70147870e-04]
# Sample point 50 predicted to be in Cluster [ 0.02352179  0.00862715  0.96785106]
# Sample point 51 predicted to be in Cluster [ 0.19779281  0.70123083  0.10097636]
# Sample point 52 predicted to be in Cluster [ 0.03552451  0.55860993  0.40586556]
# Sample point 53 predicted to be in Cluster [  1.18083268e-01   8.81660451e-01   2.56280109e-04]
# Sample point 54 predicted to be in Cluster [ 0.0336754   0.00110301  0.96522159]
# Sample point 55 predicted to be in Cluster [ 0.05829813  0.5603449   0.38135697]
# Sample point 56 predicted to be in Cluster [  4.46441931e-02   9.54972222e-01   3.83585278e-04]
# Sample point 57 predicted to be in Cluster [  5.52867678e-02   9.44417134e-01   2.96098269e-04]
# Sample point 58 predicted to be in Cluster [ 0.03877697  0.00115605  0.96006698]
# Sample point 59 predicted to be in Cluster [ 0.04985325  0.9280495   0.02209725]
# Sample point 60 predicted to be in Cluster [ 0.11653761  0.86416947  0.01929293]
# Sample point 61 predicted to be in Cluster [  1.01910915e-01   8.97665612e-01   4.23473023e-04]
# Sample point 62 predicted to be in Cluster [ 0.0330948   0.78349147  0.18341373]
# Sample point 63 predicted to be in Cluster [ 0.02384229  0.96216299  0.01399472]
# Sample point 64 predicted to be in Cluster [ 0.0328671   0.05339653  0.91373637]
# Sample point 65 predicted to be in Cluster [  8.07343284e-01   1.92656715e-01   4.49774494e-11]
# Sample point 66 predicted to be in Cluster [  9.96674112e-01   3.32588790e-03   7.39744694e-11]
# Sample point 67 predicted to be in Cluster [ 0.0269278   0.91659003  0.05648217]
# Sample point 68 predicted to be in Cluster [ 0.03507091  0.22613507  0.73879402]
# Sample point 69 predicted to be in Cluster [ 0.07646667  0.00890957  0.91462376]
# Sample point 70 predicted to be in Cluster [ 0.04989146  0.00097576  0.94913278]
# Sample point 71 predicted to be in Cluster [ 0.03319168  0.85692361  0.10988471]
# Sample point 72 predicted to be in Cluster [ 0.04245456  0.06994692  0.88759852]
# Sample point 73 predicted to be in Cluster [ 0.02927257  0.11241876  0.85830867]
# Sample point 74 predicted to be in Cluster [ 0.03647826  0.7517272   0.21179453]
# Sample point 75 predicted to be in Cluster [  9.99997216e-01   1.28167696e-16   2.78402169e-06]
# Sample point 76 predicted to be in Cluster [ 0.07306092  0.11645698  0.8104821 ]
# Sample point 77 predicted to be in Cluster [ 0.02948849  0.96876501  0.0017465 ]
# Sample point 78 predicted to be in Cluster [  4.36084744e-02   6.30130311e-04   9.55761395e-01]
# Sample point 79 predicted to be in Cluster [ 0.1071445   0.43840776  0.45444774]
# Sample point 80 predicted to be in Cluster [ 0.07217214  0.01443299  0.91339488]
# Sample point 81 predicted to be in Cluster [  2.88215071e-01   7.11782077e-01   2.85217672e-06]
# Sample point 82 predicted to be in Cluster [ 0.02685644  0.93172538  0.04141818]
# Sample point 83 predicted to be in Cluster [ 0.02373397  0.00470885  0.97155717]
# Sample point 84 predicted to be in Cluster [ 0.08540535  0.55339436  0.36120029]
# Sample point 85 predicted to be in Cluster [  2.84860213e-01   7.15111034e-01   2.87530477e-05]
# Sample point 86 predicted to be in Cluster [  6.51924589e-02   9.34523226e-01   2.84315148e-04]
# Sample point 87 predicted to be in Cluster [ 0.06439762  0.71009242  0.22550996]
# Sample point 88 predicted to be in Cluster [  7.96625769e-02   4.96685710e-05   9.20287755e-01]
# Sample point 89 predicted to be in Cluster [ 0.03225512  0.06344107  0.90430381]
# Sample point 90 predicted to be in Cluster [  1.06213152e-01   1.23394788e-05   8.93774509e-01]
# Sample point 91 predicted to be in Cluster [ 0.02481989  0.01685646  0.95832365]
# Sample point 92 predicted to be in Cluster [  5.99641315e-02   9.39370889e-01   6.64979708e-04]
# Sample point 93 predicted to be in Cluster [  1.34457501e-01   7.67389648e-04   8.64775109e-01]
# Sample point 94 predicted to be in Cluster [ 0.05765862  0.93961969  0.0027217 ]
# Sample point 95 predicted to be in Cluster [  9.94269434e-01   5.72848567e-03   2.08073988e-06]
# Sample point 96 predicted to be in Cluster [  8.87252375e-01   1.12747575e-01   5.01623212e-08]
# Sample point 97 predicted to be in Cluster [  9.82257954e-01   7.39552454e-08   1.77419717e-02]
# Sample point 98 predicted to be in Cluster [  9.51603853e-01   8.95209503e-08   4.83960577e-02]
# Sample point 99 predicted to be in Cluster [  3.12528247e-02   6.27208308e-04   9.68119967e-01]
# Sample point 100 predicted to be in Cluster [ 0.02382341  0.95275026  0.02342633]
# Sample point 101 predicted to be in Cluster [ 0.03243013  0.96545752  0.00211235]
# Sample point 102 predicted to be in Cluster [ 0.03384223  0.91633713  0.04982064]
# Sample point 103 predicted to be in Cluster [ 0.07486933  0.40246919  0.52266148]
# Sample point 104 predicted to be in Cluster [ 0.03774942  0.09887818  0.8633724 ]
# Sample point 105 predicted to be in Cluster [ 0.02871199  0.0009781   0.97030992]
# Sample point 106 predicted to be in Cluster [  6.06375031e-02   9.38975743e-01   3.86753664e-04]
# Sample point 107 predicted to be in Cluster [ 0.02410033  0.96540863  0.01049104]
# Sample point 108 predicted to be in Cluster [ 0.07478676  0.91608117  0.00913207]
# Sample point 109 predicted to be in Cluster [ 0.74444007  0.25399668  0.00156325]
# Sample point 110 predicted to be in Cluster [  2.98551596e-02   8.49103485e-04   9.69295737e-01]
# Sample point 111 predicted to be in Cluster [ 0.02470315  0.96572848  0.00956837]
# Sample point 112 predicted to be in Cluster [ 0.03575714  0.02054307  0.94369979]
# Sample point 113 predicted to be in Cluster [ 0.02353017  0.01146172  0.9650081 ]
# Sample point 114 predicted to be in Cluster [  4.30687787e-02   2.68537476e-04   9.56662684e-01]
# Sample point 115 predicted to be in Cluster [ 0.02928224  0.00100573  0.96971203]
# Sample point 116 predicted to be in Cluster [ 0.03610051  0.00386625  0.96003324]
# Sample point 117 predicted to be in Cluster [ 0.02908538  0.02806889  0.94284573]
# Sample point 118 predicted to be in Cluster [ 0.02618856  0.004697    0.96911444]
# Sample point 119 predicted to be in Cluster [ 0.02627439  0.00203624  0.97168936]
# Sample point 120 predicted to be in Cluster [ 0.02875872  0.00111392  0.97012736]
# Sample point 121 predicted to be in Cluster [ 0.05037598  0.00177771  0.94784631]
# Sample point 122 predicted to be in Cluster [  8.01333043e-01   1.48896201e-08   1.98666942e-01]
# Sample point 123 predicted to be in Cluster [ 0.05613576  0.61672606  0.32713817]
# Sample point 124 predicted to be in Cluster [ 0.03299116  0.01180229  0.95520656]
# Sample point 125 predicted to be in Cluster [ 0.06621969  0.09798609  0.83579422]
# Sample point 126 predicted to be in Cluster [ 0.03021722  0.00135863  0.96842414]
# Sample point 127 predicted to be in Cluster [ 0.02905755  0.82312367  0.14781878]
# Sample point 128 predicted to be in Cluster [  9.97371950e-01   2.62786428e-03   1.86204826e-07]
# Sample point 129 predicted to be in Cluster [ 0.0316053   0.00245799  0.96593672]
# Sample point 130 predicted to be in Cluster [ 0.02705098  0.00135021  0.97159881]
# Sample point 131 predicted to be in Cluster [  5.58633281e-01   2.65330689e-06   4.41364066e-01]
# Sample point 132 predicted to be in Cluster [ 0.04857316  0.03424496  0.91718188]
# Sample point 133 predicted to be in Cluster [  6.40749199e-02   6.39277965e-04   9.35285802e-01]
# Sample point 134 predicted to be in Cluster [  7.18677788e-02   6.77610618e-05   9.28064460e-01]
# Sample point 135 predicted to be in Cluster [  5.33864606e-02   8.74705316e-04   9.45738834e-01]
# Sample point 136 predicted to be in Cluster [ 0.03430594  0.75380599  0.21188807]
# Sample point 137 predicted to be in Cluster [ 0.45177576  0.3145722   0.23365204]
# Sample point 138 predicted to be in Cluster [ 0.03547014  0.0547915   0.90973836]
# Sample point 139 predicted to be in Cluster [ 0.05423344  0.10834583  0.83742073]
# Sample point 140 predicted to be in Cluster [ 0.03252958  0.25825116  0.70921927]
# Sample point 141 predicted to be in Cluster [ 0.02407553  0.00378648  0.97213799]
# Sample point 142 predicted to be in Cluster [  2.12190292e-01   4.49746350e-06   7.87805211e-01]
# Sample point 143 predicted to be in Cluster [  3.03864344e-02   6.86095332e-04   9.68927470e-01]
# Sample point 144 predicted to be in Cluster [ 0.10309568  0.02584348  0.87106084]
# Sample point 145 predicted to be in Cluster [  4.44660960e-02   9.55254777e-01   2.79127017e-04]
# Sample point 146 predicted to be in Cluster [  5.40193418e-02   1.62945337e-04   9.45817713e-01]
# Sample point 147 predicted to be in Cluster [ 0.04289147  0.08043789  0.87667065]
# Sample point 148 predicted to be in Cluster [  6.06083426e-02   6.81693720e-05   9.39323488e-01]
# Sample point 149 predicted to be in Cluster [  3.86703719e-02   3.36469421e-04   9.60993159e-01]
# Sample point 150 predicted to be in Cluster [  2.94724158e-02   8.91543000e-04   9.69636041e-01]
# Sample point 151 predicted to be in Cluster [ 0.10665152  0.02432545  0.86902303]
# Sample point 152 predicted to be in Cluster [ 0.02898423  0.00137852  0.96963724]
# Sample point 153 predicted to be in Cluster [ 0.04623793  0.05112735  0.90263472]
# Sample point 154 predicted to be in Cluster [  9.99999834e-01   4.74563353e-17   1.65544595e-07]
# Sample point 155 predicted to be in Cluster [  5.21769444e-02   9.47702043e-01   1.21012518e-04]
# Sample point 156 predicted to be in Cluster [ 0.03154639  0.96519545  0.00325816]
# Sample point 157 predicted to be in Cluster [ 0.02397818  0.00821981  0.96780201]
# Sample point 158 predicted to be in Cluster [ 0.03620098  0.94156887  0.02223014]
# Sample point 159 predicted to be in Cluster [  1.51500549e-01   8.48473832e-01   2.56188546e-05]
# Sample point 160 predicted to be in Cluster [ 0.04051083  0.94738252  0.01210665]
# Sample point 161 predicted to be in Cluster [  9.80659639e-01   1.79589895e-10   1.93403608e-02]
# Sample point 162 predicted to be in Cluster [ 0.02499234  0.00257219  0.97243547]
# Sample point 163 predicted to be in Cluster [ 0.03127841  0.96748063  0.00124096]
# Sample point 164 predicted to be in Cluster [ 0.05126205  0.84448563  0.10425232]
# Sample point 165 predicted to be in Cluster [ 0.02487679  0.95885558  0.01626763]
# Sample point 166 predicted to be in Cluster [ 0.02674505  0.94933246  0.02392249]
# Sample point 167 predicted to be in Cluster [ 0.15375842  0.53033422  0.31590736]
# Sample point 168 predicted to be in Cluster [  1.24956654e-01   1.24621777e-05   8.75030884e-01]
# Sample point 169 predicted to be in Cluster [  6.82761995e-02   4.41445197e-05   9.31679656e-01]
# Sample point 170 predicted to be in Cluster [  1.18441296e-01   8.81459265e-01   9.94387563e-05]
# Sample point 171 predicted to be in Cluster [  8.82575827e-02   9.11728664e-01   1.37538409e-05]
# Sample point 172 predicted to be in Cluster [ 0.12039814  0.87225608  0.00734578]
# Sample point 173 predicted to be in Cluster [  6.90173568e-02   9.30871450e-01   1.11193022e-04]
# Sample point 174 predicted to be in Cluster [ 0.1713324   0.00890643  0.81976117]
# Sample point 175 predicted to be in Cluster [  6.69718891e-02   9.32516943e-01   5.11168188e-04]
# Sample point 176 predicted to be in Cluster [ 0.03110815  0.17227391  0.79661793]
# Sample point 177 predicted to be in Cluster [  4.45601462e-02   3.61573702e-04   9.55078280e-01]
# Sample point 178 predicted to be in Cluster [ 0.03001298  0.00413512  0.9658519 ]
# Sample point 179 predicted to be in Cluster [ 0.02470433  0.01323414  0.96206153]
# Sample point 180 predicted to be in Cluster [ 0.0388259   0.70664366  0.25453044]
# Sample point 181 predicted to be in Cluster [ 0.08148832  0.91128904  0.00722264]
# Sample point 182 predicted to be in Cluster [  1.41528826e-01   8.58308025e-01   1.63149616e-04]
# Sample point 183 predicted to be in Cluster [ 0.21071556  0.75200761  0.03727683]
# Sample point 184 predicted to be in Cluster [  9.99769253e-01   2.01584279e-04   2.91626785e-05]
# Sample point 185 predicted to be in Cluster [  5.72430505e-02   8.34375997e-05   9.42673512e-01]
# Sample point 186 predicted to be in Cluster [ 0.04142089  0.0025313   0.95604781]
# Sample point 187 predicted to be in Cluster [ 0.4170894   0.53090164  0.05200896]
# Sample point 188 predicted to be in Cluster [ 0.02985775  0.93559956  0.03454269]
# Sample point 189 predicted to be in Cluster [  5.86264703e-02   9.40709670e-01   6.63859395e-04]
# Sample point 190 predicted to be in Cluster [  4.11122717e-02   1.97364304e-04   9.58690364e-01]
# Sample point 191 predicted to be in Cluster [  4.28654789e-01   4.56391736e-07   5.71344754e-01]
# Sample point 192 predicted to be in Cluster [ 0.07298825  0.00128282  0.92572893]
# Sample point 193 predicted to be in Cluster [  1.29252316e-01   8.70614225e-01   1.33459390e-04]
# Sample point 194 predicted to be in Cluster [ 0.03492094  0.00539302  0.95968604]
# Sample point 195 predicted to be in Cluster [ 0.03016193  0.03125044  0.93858763]
# Sample point 196 predicted to be in Cluster [ 0.06671705  0.21136606  0.7219169 ]
# Sample point 197 predicted to be in Cluster [ 0.03596754  0.94767036  0.0163621 ]
# Sample point 198 predicted to be in Cluster [ 0.0258389   0.03330054  0.94086055]
# Sample point 199 predicted to be in Cluster [ 0.05344752  0.00729094  0.93926154]
# Sample point 200 predicted to be in Cluster [ 0.02827661  0.96903315  0.00269024]
# Sample point 201 predicted to be in Cluster [ 0.03080564  0.96760715  0.00158721]
# Sample point 202 predicted to be in Cluster [ 0.05337209  0.2186906   0.72793731]
# Sample point 203 predicted to be in Cluster [ 0.99028796  0.00287185  0.0068402 ]
# Sample point 204 predicted to be in Cluster [  3.02747188e-01   9.49381810e-07   6.97251862e-01]
# Sample point 205 predicted to be in Cluster [  5.03555975e-02   9.49412912e-01   2.31490579e-04]
# Sample point 206 predicted to be in Cluster [  7.92850289e-02   3.02026869e-04   9.20412944e-01]
# Sample point 207 predicted to be in Cluster [ 0.09064742  0.84292023  0.06643236]
# Sample point 208 predicted to be in Cluster [ 0.07209475  0.84021805  0.0876872 ]
# Sample point 209 predicted to be in Cluster [ 0.03183175  0.96686128  0.00130697]
# Sample point 210 predicted to be in Cluster [ 0.02775139  0.00192313  0.97032548]
# Sample point 211 predicted to be in Cluster [  5.74739793e-02   9.41723879e-01   8.02141729e-04]
# Sample point 212 predicted to be in Cluster [ 0.02861587  0.00158983  0.9697943 ]
# Sample point 213 predicted to be in Cluster [ 0.03968728  0.90973086  0.05058185]
# Sample point 214 predicted to be in Cluster [ 0.04114272  0.95238685  0.00647043]
# Sample point 215 predicted to be in Cluster [ 0.02747829  0.96712655  0.00539516]
# Sample point 216 predicted to be in Cluster [  8.05828050e-02   9.19397615e-01   1.95798692e-05]
# Sample point 217 predicted to be in Cluster [  3.68711468e-02   4.40706808e-04   9.62688146e-01]
# Sample point 218 predicted to be in Cluster [  1.51092377e-01   8.48899784e-01   7.83873903e-06]
# Sample point 219 predicted to be in Cluster [  2.36475643e-01   5.56206308e-06   7.63518795e-01]
# Sample point 220 predicted to be in Cluster [  9.08915578e-02   2.03690548e-05   9.09088073e-01]
# Sample point 221 predicted to be in Cluster [ 0.08928654  0.90815105  0.00256241]
# Sample point 222 predicted to be in Cluster [  3.24123652e-02   7.98852975e-04   9.66788782e-01]
# Sample point 223 predicted to be in Cluster [ 0.03536196  0.08877347  0.87586458]
# Sample point 224 predicted to be in Cluster [  9.09763080e-02   3.00753199e-05   9.08993617e-01]
# Sample point 225 predicted to be in Cluster [ 0.04073706  0.08710742  0.87215552]
# Sample point 226 predicted to be in Cluster [ 0.03183641  0.71581911  0.25234448]
# Sample point 227 predicted to be in Cluster [ 0.03618142  0.00193643  0.96188214]
# Sample point 228 predicted to be in Cluster [ 0.36189808  0.09800918  0.54009275]
# Sample point 229 predicted to be in Cluster [ 0.02368509  0.01964718  0.95666773]
# Sample point 230 predicted to be in Cluster [ 0.03275557  0.21042314  0.75682129]
# Sample point 231 predicted to be in Cluster [ 0.09221025  0.65252889  0.25526086]
# Sample point 232 predicted to be in Cluster [ 0.02488185  0.0052416   0.96987655]
# Sample point 233 predicted to be in Cluster [ 0.96143533  0.00612293  0.03244174]
# Sample point 234 predicted to be in Cluster [ 0.02681086  0.01540194  0.9577872 ]
# Sample point 235 predicted to be in Cluster [ 0.18197734  0.36810624  0.44991642]
# Sample point 236 predicted to be in Cluster [ 0.04001279  0.00166702  0.95832018]
# Sample point 237 predicted to be in Cluster [  2.15032727e-01   1.48812386e-05   7.84952392e-01]
# Sample point 238 predicted to be in Cluster [  2.60878852e-01   2.11852086e-06   7.39119030e-01]
# Sample point 239 predicted to be in Cluster [ 0.04190658  0.06959255  0.88850087]
# Sample point 240 predicted to be in Cluster [ 0.0425146   0.04394975  0.91353565]
# Sample point 241 predicted to be in Cluster [ 0.02411387  0.00563751  0.97024862]
# Sample point 242 predicted to be in Cluster [ 0.02462334  0.00289427  0.97248239]
# Sample point 243 predicted to be in Cluster [ 0.04303531  0.50045821  0.45650647]
# Sample point 244 predicted to be in Cluster [ 0.03018425  0.91184431  0.05797144]
# Sample point 245 predicted to be in Cluster [  3.71307933e-02   9.61915244e-01   9.53962312e-04]
# Sample point 246 predicted to be in Cluster [ 0.02872583  0.00538497  0.96588921]
# Sample point 247 predicted to be in Cluster [  3.61307363e-01   6.31394780e-07   6.38692006e-01]
# Sample point 248 predicted to be in Cluster [ 0.03606142  0.03745719  0.92648139]
# Sample point 249 predicted to be in Cluster [ 0.02772222  0.02085466  0.95142312]
# Sample point 250 predicted to be in Cluster [ 0.0448884   0.00206611  0.95304549]
# Sample point 251 predicted to be in Cluster [  5.43264655e-02   9.44805542e-01   8.67993000e-04]
# Sample point 252 predicted to be in Cluster [ 0.02465719  0.00407932  0.97126349]
# Sample point 253 predicted to be in Cluster [ 0.03423787  0.23345932  0.7323028 ]
# Sample point 254 predicted to be in Cluster [ 0.03285106  0.6506532   0.31649574]
# Sample point 255 predicted to be in Cluster [  9.40627551e-02   3.93919555e-05   9.05897853e-01]
# Sample point 256 predicted to be in Cluster [ 0.05673985  0.05116419  0.89209596]
# Sample point 257 predicted to be in Cluster [ 0.03403552  0.18904402  0.77692047]
# Sample point 258 predicted to be in Cluster [ 0.06380772  0.08047051  0.85572177]
# Sample point 259 predicted to be in Cluster [ 0.03237342  0.15580119  0.81182539]
# Sample point 260 predicted to be in Cluster [ 0.07330039  0.09932857  0.82737104]
# Sample point 261 predicted to be in Cluster [  1.50248113e-01   5.49331809e-06   8.49746394e-01]
# Sample point 262 predicted to be in Cluster [ 0.02597723  0.00258148  0.97144129]
# Sample point 263 predicted to be in Cluster [ 0.09263073  0.40795781  0.49941146]
# Sample point 264 predicted to be in Cluster [  9.87890012e-02   9.01172148e-01   3.88510282e-05]
# Sample point 265 predicted to be in Cluster [ 0.03231573  0.70500763  0.26267664]
# Sample point 266 predicted to be in Cluster [ 0.03626709  0.96221748  0.00151543]
# Sample point 267 predicted to be in Cluster [ 0.02925545  0.02398012  0.94676443]
# Sample point 268 predicted to be in Cluster [ 0.02645218  0.95931485  0.01423297]
# Sample point 269 predicted to be in Cluster [  6.48805602e-02   5.64829725e-05   9.35062957e-01]
# Sample point 270 predicted to be in Cluster [  1.22554833e-01   3.78987022e-05   8.77407268e-01]
# Sample point 271 predicted to be in Cluster [ 0.04483559  0.00386303  0.95130138]
# Sample point 272 predicted to be in Cluster [ 0.29728437  0.05963943  0.6430762 ]
# Sample point 273 predicted to be in Cluster [ 0.05016004  0.00271759  0.94712237]
# Sample point 274 predicted to be in Cluster [ 0.21422202  0.09467776  0.69110021]
# Sample point 275 predicted to be in Cluster [  4.82125911e-01   2.00251711e-05   5.17854064e-01]
# Sample point 276 predicted to be in Cluster [ 0.0347109   0.10590276  0.85938634]
# Sample point 277 predicted to be in Cluster [  3.96615447e-02   2.23552126e-04   9.60114903e-01]
# Sample point 278 predicted to be in Cluster [ 0.02591509  0.00392399  0.97016092]
# Sample point 279 predicted to be in Cluster [ 0.02876671  0.85328972  0.11794357]
# Sample point 280 predicted to be in Cluster [ 0.04338174  0.00352075  0.95309751]
# Sample point 281 predicted to be in Cluster [ 0.03408181  0.73381131  0.23210688]
# Sample point 282 predicted to be in Cluster [ 0.03959646  0.11621953  0.844184  ]
# Sample point 283 predicted to be in Cluster [ 0.04114162  0.00682982  0.95202856]
# Sample point 284 predicted to be in Cluster [ 0.06785134  0.29092031  0.64122834]
# Sample point 285 predicted to be in Cluster [  7.63341717e-02   3.78338936e-04   9.23287489e-01]
# Sample point 286 predicted to be in Cluster [ 0.06904917  0.01727828  0.91367255]
# Sample point 287 predicted to be in Cluster [ 0.02667061  0.00585001  0.96747938]
# Sample point 288 predicted to be in Cluster [  4.61596024e-02   5.55080988e-04   9.53285317e-01]
# Sample point 289 predicted to be in Cluster [  8.69892376e-01   2.88507959e-09   1.30107621e-01]
# Sample point 290 predicted to be in Cluster [ 0.10217294  0.1790391   0.71878795]
# Sample point 291 predicted to be in Cluster [ 0.02827229  0.00415957  0.96756814]
# Sample point 292 predicted to be in Cluster [ 0.04246907  0.10086147  0.85666946]
# Sample point 293 predicted to be in Cluster [ 0.03324381  0.96043194  0.00632425]
# Sample point 294 predicted to be in Cluster [ 0.02925473  0.10315774  0.86758752]
# Sample point 295 predicted to be in Cluster [ 0.14155424  0.45283303  0.40561274]
# Sample point 296 predicted to be in Cluster [ 0.02338511  0.01487459  0.9617403 ]
# Sample point 297 predicted to be in Cluster [ 0.0507469   0.72386186  0.22539124]
# Sample point 298 predicted to be in Cluster [ 0.03580983  0.91235274  0.05183742]
# Sample point 299 predicted to be in Cluster [ 0.89256979  0.00468063  0.10274958]
# Sample point 300 predicted to be in Cluster [ 0.03330176  0.75436047  0.21233777]
# Sample point 301 predicted to be in Cluster [ 0.03440718  0.96232354  0.00326928]
# Sample point 302 predicted to be in Cluster [ 0.05590334  0.93999922  0.00409744]
# Sample point 303 predicted to be in Cluster [  1.18563679e-01   8.80571350e-01   8.64970703e-04]
# Sample point 304 predicted to be in Cluster [  1.12543637e-01   8.87449534e-01   6.82960747e-06]
# Sample point 305 predicted to be in Cluster [  1.84936070e-01   8.14860516e-01   2.03413093e-04]
# Sample point 306 predicted to be in Cluster [ 0.02544795  0.96925318  0.00529887]
# Sample point 307 predicted to be in Cluster [ 0.02431815  0.00734929  0.96833256]
# Sample point 308 predicted to be in Cluster [ 0.05747596  0.00309424  0.93942981]
# Sample point 309 predicted to be in Cluster [  4.32807363e-02   9.56058996e-01   6.60267622e-04]
# Sample point 310 predicted to be in Cluster [ 0.02703613  0.00210292  0.97086096]
# Sample point 311 predicted to be in Cluster [ 0.02516536  0.00621163  0.96862301]
# Sample point 312 predicted to be in Cluster [  5.86619105e-02   9.40776136e-01   5.61953453e-04]
# Sample point 313 predicted to be in Cluster [  4.04257765e-02   2.27515427e-04   9.59346708e-01]
# Sample point 314 predicted to be in Cluster [ 0.03374092  0.10725813  0.85900095]
# Sample point 315 predicted to be in Cluster [ 0.03280167  0.96392466  0.00327367]
# Sample point 316 predicted to be in Cluster [  4.24167754e-02   1.72173544e-04   9.57411051e-01]
# Sample point 317 predicted to be in Cluster [ 0.12428497  0.42833995  0.44737509]
# Sample point 318 predicted to be in Cluster [ 0.06001025  0.01171858  0.92827117]
# Sample point 319 predicted to be in Cluster [ 0.03115186  0.96732025  0.00152788]
# Sample point 320 predicted to be in Cluster [ 0.12822653  0.02469839  0.84707509]
# Sample point 321 predicted to be in Cluster [ 0.02406687  0.00514515  0.97078798]
# Sample point 322 predicted to be in Cluster [ 0.0281928  0.0136652  0.958142 ]
# Sample point 323 predicted to be in Cluster [ 0.0526798   0.24247496  0.70484524]
# Sample point 324 predicted to be in Cluster [ 0.03045722  0.00165273  0.96789005]
# Sample point 325 predicted to be in Cluster [ 0.08934876  0.79959593  0.11105531]
# Sample point 326 predicted to be in Cluster [ 0.02990893  0.00244211  0.96764896]
# Sample point 327 predicted to be in Cluster [  5.66084544e-01   3.37256560e-04   4.33578200e-01]
# Sample point 328 predicted to be in Cluster [ 0.03326938  0.00351515  0.96321547]
# Sample point 329 predicted to be in Cluster [ 0.0269301   0.01172763  0.96134226]
# Sample point 330 predicted to be in Cluster [ 0.02472973  0.00276446  0.9725058 ]
# Sample point 331 predicted to be in Cluster [ 0.02720561  0.96985829  0.0029361 ]
# Sample point 332 predicted to be in Cluster [ 0.03253981  0.00235524  0.96510495]
# Sample point 333 predicted to be in Cluster [  9.75797758e-02   9.02403208e-01   1.70165182e-05]
# Sample point 334 predicted to be in Cluster [ 0.04626673  0.0049716   0.94876166]
# Sample point 335 predicted to be in Cluster [ 0.02662916  0.88035945  0.09301138]
# Sample point 336 predicted to be in Cluster [  3.91574724e-02   3.38630474e-04   9.60503897e-01]
# Sample point 337 predicted to be in Cluster [ 0.02428556  0.00381787  0.97189656]
# Sample point 338 predicted to be in Cluster [  9.94932692e-01   1.33356376e-06   5.06597411e-03]
# Sample point 339 predicted to be in Cluster [ 0.02565947  0.02346591  0.95087462]
# Sample point 340 predicted to be in Cluster [  9.29412412e-02   9.06812544e-01   2.46214567e-04]
# Sample point 341 predicted to be in Cluster [ 0.03441343  0.95681027  0.0087763 ]
# Sample point 342 predicted to be in Cluster [  1.30819137e-01   8.68774562e-01   4.06301059e-04]
# Sample point 343 predicted to be in Cluster [  9.06371867e-02   9.09232521e-01   1.30292800e-04]
# Sample point 344 predicted to be in Cluster [  6.20397859e-02   6.27734424e-04   9.37332480e-01]
# Sample point 345 predicted to be in Cluster [ 0.1662245   0.82587032  0.00790518]
# Sample point 346 predicted to be in Cluster [ 0.02892391  0.96026268  0.0108134 ]
# Sample point 347 predicted to be in Cluster [ 0.02717809  0.86607045  0.10675147]
# Sample point 348 predicted to be in Cluster [ 0.07105438  0.08887689  0.84006873]
# Sample point 349 predicted to be in Cluster [ 0.0293956   0.96851608  0.00208832]
# Sample point 350 predicted to be in Cluster [  4.22718603e-02   6.95335876e-04   9.57032804e-01]
# Sample point 351 predicted to be in Cluster [  3.80973074e-02   9.61456603e-01   4.46089196e-04]
# Sample point 352 predicted to be in Cluster [  5.98853915e-01   1.48325923e-04   4.00997759e-01]
# Sample point 353 predicted to be in Cluster [  2.22230739e-01   7.77767968e-01   1.29347963e-06]
# Sample point 354 predicted to be in Cluster [ 0.03331803  0.21273056  0.75395141]
# Sample point 355 predicted to be in Cluster [  9.92410385e-01   3.19098052e-04   7.27051706e-03]
# Sample point 356 predicted to be in Cluster [  9.93642032e-01   2.33245697e-11   6.35796824e-03]
# Sample point 357 predicted to be in Cluster [  8.75915995e-01   1.24083997e-01   8.33874156e-09]
# Sample point 358 predicted to be in Cluster [ 0.04308737  0.19548386  0.76142877]
# Sample point 359 predicted to be in Cluster [ 0.3580349   0.05525658  0.58670852]
# Sample point 360 predicted to be in Cluster [ 0.02361592  0.00577513  0.97060895]
# Sample point 361 predicted to be in Cluster [  9.72591888e-02   5.92626361e-05   9.02681549e-01]
# Sample point 362 predicted to be in Cluster [ 0.11007254  0.00321604  0.88671142]
# Sample point 363 predicted to be in Cluster [ 0.30572247  0.23199667  0.46228086]
# Sample point 364 predicted to be in Cluster [ 0.09139053  0.00440584  0.90420363]
# Sample point 365 predicted to be in Cluster [ 0.02805222  0.92376176  0.04818602]
# Sample point 366 predicted to be in Cluster [ 0.03624148  0.00112917  0.96262935]
# Sample point 367 predicted to be in Cluster [  9.65804440e-02   1.34271570e-04   9.03285284e-01]
# Sample point 368 predicted to be in Cluster [  4.55739987e-02   1.54002797e-04   9.54271998e-01]
# Sample point 369 predicted to be in Cluster [  3.97220466e-01   4.93544123e-07   6.02779041e-01]
# Sample point 370 predicted to be in Cluster [ 0.02858319  0.06629523  0.90512159]
# Sample point 371 predicted to be in Cluster [ 0.02582851  0.00872256  0.96544893]
# Sample point 372 predicted to be in Cluster [ 0.0303238   0.03084603  0.93883018]
# Sample point 373 predicted to be in Cluster [ 0.03258773  0.66577391  0.30163835]
# Sample point 374 predicted to be in Cluster [ 0.03344356  0.00305207  0.96350437]
# Sample point 375 predicted to be in Cluster [ 0.1992308   0.00199005  0.79877916]
# Sample point 376 predicted to be in Cluster [ 0.02678398  0.93800995  0.03520607]
# Sample point 377 predicted to be in Cluster [  3.34855976e-02   9.28144360e-04   9.65586258e-01]
# Sample point 378 predicted to be in Cluster [  8.22210241e-02   8.12530444e-04   9.16966445e-01]
# Sample point 379 predicted to be in Cluster [ 0.31456575  0.58030148  0.10513277]
# Sample point 380 predicted to be in Cluster [ 0.02592642  0.00182289  0.97225069]
# Sample point 381 predicted to be in Cluster [ 0.03095228  0.00196527  0.96708245]
# Sample point 382 predicted to be in Cluster [ 0.03549251  0.61551316  0.34899433]
# Sample point 383 predicted to be in Cluster [ 0.0630868   0.00656412  0.93034908]
# Sample point 384 predicted to be in Cluster [ 0.03590641  0.38248437  0.58160922]
# Sample point 385 predicted to be in Cluster [  3.44862371e-02   3.90239761e-04   9.65123523e-01]
# Sample point 386 predicted to be in Cluster [ 0.07782405  0.03214484  0.89003111]
# Sample point 387 predicted to be in Cluster [ 0.02841724  0.00116066  0.97042209]
# Sample point 388 predicted to be in Cluster [  4.96534760e-02   1.56369599e-04   9.50190154e-01]
# Sample point 389 predicted to be in Cluster [  3.15026771e-02   6.07896394e-04   9.67889426e-01]
# Sample point 390 predicted to be in Cluster [ 0.03104139  0.00103361  0.967925  ]
# Sample point 391 predicted to be in Cluster [ 0.04283182  0.00137104  0.95579714]
# Sample point 392 predicted to be in Cluster [ 0.34203822  0.01586036  0.64210142]
# Sample point 393 predicted to be in Cluster [ 0.02899506  0.02331774  0.9476872 ]
# Sample point 394 predicted to be in Cluster [  3.93659898e-02   3.39334030e-04   9.60294676e-01]
# Sample point 395 predicted to be in Cluster [ 0.03140042  0.0039227   0.96467688]
# Sample point 396 predicted to be in Cluster [ 0.02727392  0.92074771  0.05197837]
# Sample point 397 predicted to be in Cluster [  7.93085211e-02   5.22315137e-05   9.20639247e-01]
# Sample point 398 predicted to be in Cluster [  1.60934326e-01   4.76008220e-06   8.39060914e-01]
# Sample point 399 predicted to be in Cluster [  4.39208193e-02   4.47143236e-04   9.55632037e-01]
# Sample point 400 predicted to be in Cluster [  4.38703765e-02   1.73582898e-04   9.55956041e-01]
# Sample point 401 predicted to be in Cluster [ 0.11035981  0.00096901  0.88867118]
# Sample point 402 predicted to be in Cluster [  9.73526997e-02   1.73926862e-05   9.02629908e-01]
# Sample point 403 predicted to be in Cluster [ 0.08149624  0.2425504   0.67595336]
# Sample point 404 predicted to be in Cluster [ 0.0263376   0.06243389  0.91122852]
# Sample point 405 predicted to be in Cluster [ 0.03862441  0.00199515  0.95938044]
# Sample point 406 predicted to be in Cluster [ 0.03319946  0.13067384  0.8361267 ]
# Sample point 407 predicted to be in Cluster [ 0.02556024  0.96507784  0.00936192]
# Sample point 408 predicted to be in Cluster [ 0.05966094  0.57784678  0.36249228]
# Sample point 409 predicted to be in Cluster [ 0.03342568  0.59850898  0.36806534]
# Sample point 410 predicted to be in Cluster [ 0.04425304  0.33244797  0.62329899]
# Sample point 411 predicted to be in Cluster [ 0.03173898  0.02121387  0.94704714]
# Sample point 412 predicted to be in Cluster [  8.67987384e-01   1.32012319e-01   2.97180611e-07]
# Sample point 413 predicted to be in Cluster [ 0.031778    0.19592468  0.77229732]
# Sample point 414 predicted to be in Cluster [ 0.03511497  0.03425657  0.93062846]
# Sample point 415 predicted to be in Cluster [ 0.03075963  0.86378158  0.10545879]
# Sample point 416 predicted to be in Cluster [ 0.03092852  0.96284576  0.00622573]
# Sample point 417 predicted to be in Cluster [ 0.04415152  0.93232734  0.02352113]
# Sample point 418 predicted to be in Cluster [  1.14315190e-01   8.85658551e-01   2.62590120e-05]
# Sample point 419 predicted to be in Cluster [ 0.04857323  0.25365907  0.6977677 ]
# Sample point 420 predicted to be in Cluster [  6.89872066e-02   9.30787180e-01   2.25613884e-04]
# Sample point 421 predicted to be in Cluster [ 0.03082639  0.8197691   0.14940451]
# Sample point 422 predicted to be in Cluster [ 0.02680311  0.04736002  0.92583686]
# Sample point 423 predicted to be in Cluster [ 0.04151849  0.29338952  0.66509199]
# Sample point 424 predicted to be in Cluster [ 0.05491738  0.70679595  0.23828667]
# Sample point 425 predicted to be in Cluster [ 0.05395839  0.00099054  0.94505107]
# Sample point 426 predicted to be in Cluster [ 0.02438142  0.93331703  0.04230155]
# Sample point 427 predicted to be in Cluster [ 0.04750742  0.12202203  0.83047055]
# Sample point 428 predicted to be in Cluster [ 0.08621883  0.20205615  0.71172503]
# Sample point 429 predicted to be in Cluster [ 0.06948762  0.00313552  0.92737686]
# Sample point 430 predicted to be in Cluster [ 0.06574603  0.18201499  0.75223898]
# Sample point 431 predicted to be in Cluster [ 0.03262746  0.24380443  0.72356811]
# Sample point 432 predicted to be in Cluster [ 0.06456965  0.10315944  0.83227092]
# Sample point 433 predicted to be in Cluster [ 0.04709415  0.0122117   0.94069415]
# Sample point 434 predicted to be in Cluster [ 0.04365386  0.64141658  0.31492956]
# Sample point 435 predicted to be in Cluster [ 0.05807326  0.1079619   0.83396484]
# Sample point 436 predicted to be in Cluster [  1.57608677e-01   1.65996926e-04   8.42225326e-01]
# Sample point 437 predicted to be in Cluster [  3.80207283e-02   9.61321129e-01   6.58143117e-04]
# Sample point 438 predicted to be in Cluster [ 0.02599723  0.0019873   0.97201548]
# Sample point 439 predicted to be in Cluster [ 0.9300582   0.01265757  0.05728423]

# %% [markdown]
# **回答:**  对每一个分类，取概率最大值表示。
#             我之前预测的样本是： 95 咖啡店 75 零售店 85 超市
#             现在预测的是：95 零售店 75 零售店 85 超市
#             和我之前的猜测还是有两个是一致的。

# %% [markdown]
# ## 结论
#
# 在最后一部分中，你要学习如何使用已经被分类的数据。首先，你要考虑不同组的客户**客户分类**，针对不同的派送策略受到的影响会有什么不同。其次，你要考虑到，每一个客户都被打上了标签（客户属于哪一个分类）可以给客户数据提供一个多一个特征。最后，你会把客户分类与一个数据中的隐藏变量做比较，看一下这个分类是否辨识了特定的关系。

# %% [markdown]
# ### 问题 10
# 在对他们的服务或者是产品做细微的改变的时候，公司经常会使用[A/B tests](https://en.wikipedia.org/wiki/A/B_testing)以确定这些改变会对客户产生积极作用还是消极作用。这个批发商希望考虑将他的派送服务从每周5天变为每周3天，但是他只会对他客户当中对此有积极反馈的客户采用。*这个批发商应该如何利用客户分类来知道哪些客户对它的这个派送策略的改变有积极的反馈，如果有的话？你需要给出在这个情形下A/B 测试具体的实现方法，以及最终得出结论的依据是什么？*
# **提示：** 我们能假设这个改变对所有的客户影响都一致吗？我们怎样才能够确定它对于哪个类型的客户影响最大？

# %% [markdown]
# **回答：** 可以每种客户，各选择5~10个，进行A，B两种形式的派送，比如A改为每周3天，B保持每周5天。然后依据这种派送方式的客户联系反馈来判断是否积极。我们不能假设这个改变对所有客户都一致，特别比如饭点一类对新鲜度要求高的客户，减少派送天数意味着新鲜度的流失。但可以根据统计的反馈，来判断哪一类用户对派送天数有所要求，因为有要求的话必然会有负面的反馈。相反的就是正面的反馈。最终根据统计的结果进行下一步的扩大动作。

# %% [markdown]
# ### 问题 11
# 通过聚类技术，我们能够将原有的没有标记的数据集中的附加结构分析出来。因为每一个客户都有一个最佳的划分（取决于你选择使用的聚类算法），我们可以把*用户分类*作为数据的一个[**工程特征**](https://en.wikipedia.org/wiki/Feature_learning#Unsupervised_feature_learning)。假设批发商最近迎来十位新顾客，并且他已经为每位顾客每个产品类别年度采购额进行了预估。进行了这些估算之后，批发商该如何运用它的预估和**非监督学习的结果**来对这十个新的客户进行更好的预测？
#
# **提示：**在下面的代码单元中，我们提供了一个已经做好聚类的数据（聚类结果为数据中的cluster属性），我们将在这个数据集上做一个小实验。尝试运行下面的代码看看我们尝试预测‘Region’的时候，如果存在聚类特征'cluster'与不存在相比对最终的得分会有什么影响？这对你有什么启发？

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# 读取包含聚类结果的数据
cluster_data = pd.read_csv("cluster.csv")
y = cluster_data['Region']
X = cluster_data.drop(['Region'], axis = 1)

# 划分训练集测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=24)

clf = RandomForestClassifier(random_state=24)
clf.fit(X_train, y_train)
print "使用cluster特征的得分", clf.score(X_test, y_test)

# 移除cluster特征
X_train = X_train.copy()
X_train.drop(['cluster'], axis=1, inplace=True)
X_test = X_test.copy()
X_test.drop(['cluster'], axis=1, inplace=True)
clf.fit(X_train, y_train)
print "不使用cluster特征的得分", clf.score(X_test, y_test)
# Out:
# 使用cluster特征的得分 0.666666666667
# 不使用cluster特征的得分 0.64367816092

# %% [markdown]
# **回答：** 很明显，学习的数据越丰富，特征得分是会更好的。新客户的采购预估可以直接放入模型进行计算。

# %% [markdown]
# ### 可视化内在的分布
#
# 在这个项目的开始，我们讨论了从数据集中移除`'Channel'`和`'Region'`特征，这样在分析过程中我们就会着重分析用户产品类别。通过重新引入`Channel`这个特征到数据集中，并施加和原来数据集同样的PCA变换的时候我们将能够发现数据集产生一个有趣的结构。
#
# 运行下面的代码单元以查看哪一个数据点在降维的空间中被标记为`'HoReCa'` (旅馆/餐馆/咖啡厅)或者`'Retail'`。另外，你将发现样本点在图中被圈了出来，用以显示他们的标签。

# %%
# 根据‘Channel‘数据显示聚类的结果
vs.channel_results(reduced_data, outliers, pca_samples)

# %% [markdown]
# ### 问题 12
#
# *你选择的聚类算法和聚类点的数目，与内在的旅馆/餐馆/咖啡店和零售商的分布相比，有足够好吗？根据这个分布有没有哪个簇能够刚好划分成'零售商'或者是'旅馆/饭店/咖啡馆'？你觉得这个分类和前面你对于用户分类的定义是一致的吗？*

# %% [markdown]
# **回答：**我觉得结果还是相对可以接受的。大致还是分开成为了两个簇。和前面我对于用户的分类，基本接近。因为我之前的算法，对于2个或者3个聚类数的分数是接近的。如此看来其实聚类数是2个的话更接近数据源的分类。

# %% [markdown]
# > **注意**: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出**File -> Download as -> HTML (.html)**把这个 HTML 和这个 iPython notebook 一起做为你的作业提交。
